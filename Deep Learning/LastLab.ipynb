# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch):
    return 1.0 / (1.0 + np.exp(-batch))

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

def softmax(batch):
    m = as_matrix(np.max(batch, axis=1))
    exponents = np.exp(batch - m)
    return exponents / as_matrix(np.sum(exponents, axis=1))

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Part 1: $L^1$ and $L^2$ penalties

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, momentum, l1_penalty, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l1_penalty = l1_penalty
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:, :-1])
    hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size))
    
    visible = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count
    
    return error

# %%
def train_epoch(rbm, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            rbm.momentum = 0.8

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size)
        elapsed = time.time() - start_time
        
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### CDK with regulatization
#
# Implement the Contrastive Divergence algorithm with $L^1$ and $L^2$ penalties. If
# ```python
# rbm.l1_penalty > 0
# ```
# the algorithm should constrain the weights with $L^1$ penalty. Otherwise, if
# ```python
# rbm.l2_penalty > 0
# ```
# the algorithm should constrain the weights with $L^2$ penalty.
#
# Do **not** apply the penalties to the biases!

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
   
    positive_hidden[:, :-1] = sigmoid(positive_visible @ rbm.W[:, :-1])
    positive_gradient = positive_visible.transpose() @ positive_hidden
    
    negative_hidden[:, :-1]=(positive_hidden[:,:-1] > rand(observations_count , rbm.hidden_size)).astype(np.float32)
    
    for i in range(k):
        negative_visible[:, :-1]=sigmoid(negative_hidden @ rbm.W[:-1, :].transpose())>rand(observations_count,rbm.visible_size).astype(np.float32)
        negative_hidden[:, :-1]=sigmoid(negative_visible @ rbm.W[:, :-1]) 
        if i<k-1:
            negative_hidden[:,:-1]=(negative_hidden[:,:-1]>rand(observations_count,rbm.hidden_size).astype(np.float32))

    negative_gradient=negative_visible.transpose() @ negative_hidden
    
    
    rbm.M=(rbm.momentum * rbm.M) + (rbm.learning_rate * positive_gradient)/observations_count - (rbm.learning_rate * negative_gradient)/observations_count
    #-++-
    rbm.W=rbm.W + rbm.M

# %% [markdown]
# ## Comparison of regularization penalties

# %%
DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

# %% [markdown]
# ### RBM with no regularization

# %%
L1_PENALTY = 0.0
L2_PENALTY = 0.0

np.random.seed(1234)
rbm_plain = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L1_PENALTY, L2_PENALTY)

run_training(rbm_plain, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)
# Out:
# Epoch 1:	########################################	elapsed: 1.72s, reconstruction error: 26.21
# Epoch 2:	########################################	elapsed: 1.40s, reconstruction error: 21.11
# Epoch 3:	########################################	elapsed: 1.40s, reconstruction error: 18.69
# Epoch 4:	########################################	elapsed: 1.37s, reconstruction error: 17.28
# Epoch 5:	########################################	elapsed: 1.37s, reconstruction error: 16.38
# Epoch 6:	########################################	elapsed: 1.56s, reconstruction error: 14.93
# Epoch 7:	########################################	elapsed: 1.64s, reconstruction error: 13.96
# Epoch 8:	########################################	elapsed: 1.80s, reconstruction error: 13.52
# Epoch 9:	########################################	elapsed: 1.81s, reconstruction error: 12.80
# Epoch 10:	########################################	elapsed: 2.07s, reconstruction error: 12.39
# Epoch 11:	########################################	elapsed: 2.07s, reconstruction error: 12.06
# Epoch 12:	########################################	elapsed: 1.78s, reconstruction error: 11.86
# Epoch 13:	########################################	elapsed: 1.69s, reconstruction error: 11.42
# Epoch 14:	########################################	elapsed: 1.72s, reconstruction error: 11.42
# Epoch 15:	########################################	elapsed: 1.67s, reconstruction error: 11.25
# Epoch 16:	########################################	elapsed: 1.59s, reconstruction error: 11.21
# Epoch 17:	########################################	elapsed: 1.74s, reconstruction error: 11.15
# Epoch 18:	########################################	elapsed: 1.69s, reconstruction error: 10.84
# Epoch 19:	########################################	elapsed: 1.70s, reconstruction error: 10.74
# Epoch 20:	########################################	elapsed: 1.81s, reconstruction error: 10.55
# Epoch 21:	########################################	elapsed: 1.75s, reconstruction error: 10.76
# Epoch 22:	########################################	elapsed: 1.71s, reconstruction error: 10.63
# Epoch 23:	########################################	elapsed: 1.81s, reconstruction error: 10.56
# Epoch 24:	########################################	elapsed: 1.79s, reconstruction error: 10.81
# Epoch 25:	########################################	elapsed: 1.83s, reconstruction error: 10.50
# Epoch 26:	########################################	elapsed: 1.66s, reconstruction error: 10.50
# Epoch 27:	########################################	elapsed: 1.74s, reconstruction error: 10.50
# Epoch 28:	########################################	elapsed: 1.78s, reconstruction error: 10.34
# Epoch 29:	########################################	elapsed: 1.79s, reconstruction error: 10.30
# Epoch 30:	########################################	elapsed: 1.77s, reconstruction error: 10.39
# Epoch 31:	########################################	elapsed: 1.77s, reconstruction error: 10.45
# Epoch 32:	########################################	elapsed: 1.75s, reconstruction error: 10.46
# Epoch 33:	########################################	elapsed: 1.79s, reconstruction error: 10.37
# Epoch 34:	########################################	elapsed: 1.75s, reconstruction error: 10.30
# Epoch 35:	########################################	elapsed: 1.66s, reconstruction error: 10.14
# Epoch 36:	########################################	elapsed: 1.69s, reconstruction error: 10.34
# Epoch 37:	########################################	elapsed: 1.69s, reconstruction error: 10.26
# Epoch 38:	########################################	elapsed: 1.72s, reconstruction error: 10.28
# Epoch 39:	########################################	elapsed: 1.72s, reconstruction error: 10.30
# Epoch 40:	########################################	elapsed: 1.80s, reconstruction error: 10.27
# Epoch 41:	########################################	elapsed: 1.68s, reconstruction error: 10.29
# Epoch 42:	########################################	elapsed: 1.80s, reconstruction error: 10.10
# Epoch 43:	########################################	elapsed: 1.75s, reconstruction error: 10.23
# Epoch 44:	########################################	elapsed: 1.68s, reconstruction error: 10.09
# Epoch 45:	########################################	elapsed: 1.78s, reconstruction error: 10.18
# Epoch 46:	########################################	elapsed: 1.70s, reconstruction error: 10.10
# Epoch 47:	########################################	elapsed: 1.69s, reconstruction error: 10.23
# Epoch 48:	########################################	elapsed: 1.79s, reconstruction error: 10.16
# Epoch 49:	########################################	elapsed: 1.87s, reconstruction error: 10.10
# Epoch 50:	########################################	elapsed: 1.80s, reconstruction error: 9.94
# Training finished!

# %% [markdown]
# ### RBM with $L^1$ penalty

# %%
L1_PENALTY = 0.0001
L2_PENALTY = 0.0

np.random.seed(1234)
rbm_l1 = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L1_PENALTY, L2_PENALTY)

run_training(rbm_l1, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)
# Out:
# Epoch 1:	########################################	elapsed: 1.68s, reconstruction error: 26.21
# Epoch 2:	########################################	elapsed: 1.60s, reconstruction error: 21.11
# Epoch 3:	########################################	elapsed: 1.67s, reconstruction error: 18.69
# Epoch 4:	########################################	elapsed: 1.64s, reconstruction error: 17.28
# Epoch 5:	########################################	elapsed: 1.39s, reconstruction error: 16.38
# Epoch 6:	########################################	elapsed: 1.41s, reconstruction error: 14.93
# Epoch 7:	########################################	elapsed: 1.47s, reconstruction error: 13.96
# Epoch 8:	########################################	elapsed: 1.70s, reconstruction error: 13.52
# Epoch 9:	########################################	elapsed: 1.55s, reconstruction error: 12.80
# Epoch 10:	########################################	elapsed: 1.56s, reconstruction error: 12.39
# Epoch 11:	########################################	elapsed: 1.64s, reconstruction error: 12.06
# Epoch 12:	########################################	elapsed: 1.54s, reconstruction error: 11.86
# Epoch 13:	########################################	elapsed: 1.56s, reconstruction error: 11.42
# Epoch 14:	########################################	elapsed: 1.57s, reconstruction error: 11.42
# Epoch 15:	########################################	elapsed: 1.58s, reconstruction error: 11.25
# Epoch 16:	########################################	elapsed: 1.62s, reconstruction error: 11.21
# Epoch 17:	########################################	elapsed: 1.61s, reconstruction error: 11.15
# Epoch 18:	########################################	elapsed: 1.65s, reconstruction error: 10.84
# Epoch 19:	########################################	elapsed: 1.64s, reconstruction error: 10.74
# Epoch 20:	########################################	elapsed: 1.64s, reconstruction error: 10.55
# Epoch 21:	########################################	elapsed: 1.64s, reconstruction error: 10.76
# Epoch 22:	########################################	elapsed: 1.65s, reconstruction error: 10.63
# Epoch 23:	########################################	elapsed: 1.61s, reconstruction error: 10.56
# Epoch 24:	########################################	elapsed: 1.55s, reconstruction error: 10.81
# Epoch 25:	########################################	elapsed: 1.55s, reconstruction error: 10.50
# Epoch 26:	########################################	elapsed: 1.60s, reconstruction error: 10.50
# Epoch 27:	########################################	elapsed: 1.61s, reconstruction error: 10.50
# Epoch 28:	########################################	elapsed: 1.64s, reconstruction error: 10.34
# Epoch 29:	########################################	elapsed: 1.66s, reconstruction error: 10.30
# Epoch 30:	########################################	elapsed: 1.60s, reconstruction error: 10.39
# Epoch 31:	########################################	elapsed: 1.65s, reconstruction error: 10.45
# Epoch 32:	########################################	elapsed: 1.62s, reconstruction error: 10.46
# Epoch 33:	########################################	elapsed: 1.58s, reconstruction error: 10.37
# Epoch 34:	########################################	elapsed: 1.63s, reconstruction error: 10.30
# Epoch 35:	########################################	elapsed: 1.65s, reconstruction error: 10.14
# Epoch 36:	########################################	elapsed: 1.66s, reconstruction error: 10.34
# Epoch 37:	########################################	elapsed: 1.64s, reconstruction error: 10.26
# Epoch 38:	########################################	elapsed: 1.61s, reconstruction error: 10.28
# Epoch 39:	########################################	elapsed: 1.60s, reconstruction error: 10.30
# Epoch 40:	########################################	elapsed: 1.59s, reconstruction error: 10.27
# Epoch 41:	########################################	elapsed: 1.61s, reconstruction error: 10.29
# Epoch 42:	########################################	elapsed: 1.65s, reconstruction error: 10.10
# Epoch 43:	########################################	elapsed: 1.66s, reconstruction error: 10.23
# Epoch 44:	########################################	elapsed: 1.73s, reconstruction error: 10.09
# Epoch 45:	########################################	elapsed: 1.72s, reconstruction error: 10.18
# Epoch 46:	########################################	elapsed: 1.62s, reconstruction error: 10.10
# Epoch 47:	########################################	elapsed: 1.62s, reconstruction error: 10.23
# Epoch 48:	########################################	elapsed: 1.71s, reconstruction error: 10.16
# Epoch 49:	########################################	elapsed: 1.80s, reconstruction error: 10.10
# Epoch 50:	########################################	elapsed: 1.67s, reconstruction error: 9.94
# Training finished!

# %% [markdown]
# ### RBM with $L^2$ penalty

# %%
L1_PENALTY = 0.0
L2_PENALTY = 0.0005

np.random.seed(1234)
rbm_l2 = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L1_PENALTY, L2_PENALTY)

run_training(rbm_l2, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)
# Out:
# Epoch 1:	########################################	elapsed: 1.99s, reconstruction error: 26.21
# Epoch 2:	########################################	elapsed: 1.80s, reconstruction error: 21.11
# Epoch 3:	########################################	elapsed: 1.70s, reconstruction error: 18.69
# Epoch 4:	########################################	elapsed: 1.63s, reconstruction error: 17.28
# Epoch 5:	########################################	elapsed: 1.58s, reconstruction error: 16.38
# Epoch 6:	########################################	elapsed: 1.59s, reconstruction error: 14.93
# Epoch 7:	########################################	elapsed: 1.74s, reconstruction error: 13.96
# Epoch 8:	########################################	elapsed: 1.73s, reconstruction error: 13.52
# Epoch 9:	########################################	elapsed: 1.69s, reconstruction error: 12.80
# Epoch 10:	########################################	elapsed: 1.73s, reconstruction error: 12.39
# Epoch 11:	########################################	elapsed: 1.72s, reconstruction error: 12.06
# Epoch 12:	########################################	elapsed: 1.72s, reconstruction error: 11.86
# Epoch 13:	########################################	elapsed: 1.86s, reconstruction error: 11.42
# Epoch 14:	########################################	elapsed: 1.72s, reconstruction error: 11.42
# Epoch 15:	########################################	elapsed: 1.74s, reconstruction error: 11.25
# Epoch 16:	########################################	elapsed: 1.74s, reconstruction error: 11.21
# Epoch 17:	########################################	elapsed: 1.77s, reconstruction error: 11.15
# Epoch 18:	########################################	elapsed: 1.67s, reconstruction error: 10.84
# Epoch 19:	########################################	elapsed: 1.61s, reconstruction error: 10.74
# Epoch 20:	########################################	elapsed: 1.61s, reconstruction error: 10.55
# Epoch 21:	########################################	elapsed: 1.71s, reconstruction error: 10.76
# Epoch 22:	########################################	elapsed: 1.74s, reconstruction error: 10.63
# Epoch 23:	########################################	elapsed: 1.75s, reconstruction error: 10.56
# Epoch 24:	########################################	elapsed: 1.70s, reconstruction error: 10.81
# Epoch 25:	########################################	elapsed: 1.78s, reconstruction error: 10.50
# Epoch 26:	########################################	elapsed: 1.87s, reconstruction error: 10.50
# Epoch 27:	########################################	elapsed: 1.80s, reconstruction error: 10.50
# Epoch 28:	########################################	elapsed: 1.69s, reconstruction error: 10.34
# Epoch 29:	########################################	elapsed: 1.72s, reconstruction error: 10.30
# Epoch 30:	########################################	elapsed: 1.73s, reconstruction error: 10.39
# Epoch 31:	########################################	elapsed: 1.63s, reconstruction error: 10.45
# Epoch 32:	########################################	elapsed: 1.64s, reconstruction error: 10.46
# Epoch 33:	########################################	elapsed: 1.67s, reconstruction error: 10.37
# Epoch 34:	########################################	elapsed: 1.72s, reconstruction error: 10.30
# Epoch 35:	########################################	elapsed: 1.77s, reconstruction error: 10.14
# Epoch 36:	########################################	elapsed: 1.70s, reconstruction error: 10.34
# Epoch 37:	########################################	elapsed: 1.70s, reconstruction error: 10.26
# Epoch 38:	########################################	elapsed: 1.69s, reconstruction error: 10.28
# Epoch 39:	########################################	elapsed: 1.73s, reconstruction error: 10.30
# Epoch 40:	########################################	elapsed: 1.69s, reconstruction error: 10.27
# Epoch 41:	########################################	elapsed: 1.77s, reconstruction error: 10.29
# Epoch 42:	########################################	elapsed: 1.72s, reconstruction error: 10.10
# Epoch 43:	########################################	elapsed: 1.77s, reconstruction error: 10.23
# Epoch 44:	########################################	elapsed: 1.67s, reconstruction error: 10.09
# Epoch 45:	########################################	elapsed: 1.68s, reconstruction error: 10.18
# Epoch 46:	########################################	elapsed: 1.64s, reconstruction error: 10.10
# Epoch 47:	########################################	elapsed: 1.73s, reconstruction error: 10.23
# Epoch 48:	########################################	elapsed: 1.72s, reconstruction error: 10.16
# Epoch 49:	########################################	elapsed: 1.85s, reconstruction error: 10.10
# Epoch 50:	########################################	elapsed: 2.01s, reconstruction error: 9.94
# Training finished!

# %% [markdown]
# ### Plain filters

# %%
draw_filters(rbm_plain)

# %% [markdown]
# ### $L^1$ filters

# %%
draw_filters(rbm_l1)

# %% [markdown]
# ### $L^2$ filters

# %%
draw_filters(rbm_l2)

# %% [markdown]
# # Part 2: MLP pretraining

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, momentum, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %% [markdown]
# ### Forward pass

# %%
def forward_pass(mlp, batch, compute_derivatives):
    visible = batch
    
    for layer_idx, layer in enumerate(mlp):
        z = visible @ layer.W
        layer.activations =append_ones(layer.activation_fun(z))

        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(z)
        
        visible = layer.activations
        
    return visible[:, :-1]

# %% [markdown]
# ### Error backpropagation
#
# Extend the implementation of error backpropagation (from Lab 6) with $L^2$ penalty. Apply the penalty when:
# ```python
# rbm.l2_penalty > 0
# ```
#
# Do **not** apply the penalty to the biases.

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    error('Error backpropagation is unimplemented')
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations
            
          #  raise Exception("Calculate the deltas in 'prev_layer'")
            # prev_layer.deltas = ???
            prev_layer.deltas = (layer.deltas @ layer.W[0:-1, : ].transpose()) * prev_layer.d_activations
        else:
            visible = batch
        
       #raise Exception("Update the momentum matrix with gradient from error backpropagation")
        # layer.M = ???
        gradient=(visible.transpose()@layer.deltas)/observations_count
        layer.M=(layer.M* layer.momentum) - (layer.learning_rate*gradient)
        layer.W += layer.M
        
        raise Exception("If layer.l2_penalty > 0, update the momentum matrix with gradient from L2 penalty")
        # layer.M = ???
        
        layer.W += layer.M

# %% [markdown]
# ### MLP training

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        
        y = forward_pass(mlp, batch, True)
        
        #raise Exception("Delta in the sofmax layer is unimplemented!")
        mlp[-1].deltas = y - batch_labels
        
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch)
        
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %%
def classify(mlp, batch):
    probabilities = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def run_mlp_training(mlp, train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count):
    
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            for layer in mlp: layer.momentum = 0.9
        
        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time

        predictions = classify(mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")
    
def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ## DBN Pretraining

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:, :-1])
    hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
    visible = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count
    
    return error

# %%
def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    # dataset = ???
    dataset=propagate_up(dbn,layer_idx,dataset)
    raise Exception("This part is unimplemented.")
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def train_dbn(dbn, dataset, monitoring_set, batch_size, epochs_count):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx))
        
        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = 0.9

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# ##  Initializing MLP with DBN weights
#
# Implement initialization of MLP weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the MLP weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_mlp(mlp, dbn):
    raise Exception('Initialization of MLP from a pre-trained network is unimplemented')

# %% [markdown]
# # MNIST digits classification

# %%
np.random.seed(1234)

DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %% [markdown]
# ### Plain vs pretrained MLP comparison

# %%
from IPython.core.display import HTML

def compare_pretraining_results(mlp, dbn,
                                train_set, train_labels,
                                validation_set, validation_labels,
                                monitoring_set,
                                batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>Plain MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in the plain MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>DBN training</h3>'))
    train_dbn(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    for layer in mlp:
        layer.reset()
    
    initialize_mlp(mlp, dbn)
    
    display(HTML('<h3>Finetuning pretrained MLP</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_filters(dbn[0])
    
    display(HTML('<h3>Input layer filters in the pretrained & finetuned MLP</h3>'))
    draw_layer_filters(mlp[0])

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 256

BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
SOFTMAX_LEARNING_RATE = 0.15
MOMENTUM = 0.5
L2_PENALTY = 0.00002

# %% [markdown]
# ### Shallow neural network

# %%
shallow_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM, L2_PENALTY)
]

shallow_dbn = [
    Rbm(mlp_layer.visible_size,
        mlp_layer.hidden_size,
        LEARNING_RATE, MOMENTUM, 0.0, L2_PENALTY) for mlp_layer in shallow_mlp[:-1]
]

compare_pretraining_results(shallow_mlp, shallow_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-913d1f24d6b1> in <module>()
#      15                             mnist_test_images, mnist_test_labels,
#      16                             monitoring_set,
# ---> 17                             BATCH_SIZE, EPOCHS_COUNT)
#
# <ipython-input-28-1a3328aae0f3> in compare_pretraining_results(mlp, dbn, train_set, train_labels, validation_set, validation_labels, monitoring_set, batch_size, epochs_count)
#      13                      train_set, train_labels,
#      14                      validation_set, validation_labels,
# ---> 15                      batch_size, epochs_count)
#      16
#      17     display(HTML('<h3>Input layer filters in the plain MLP</h3>'))
#
# <ipython-input-21-221d1846516e> in run_mlp_training(mlp, train_set, train_labels, validation_set, validation_labels, batch_size, epochs_count)
#      14
#      15         start_time = time.time()
# ---> 16         train_mlp(mlp, train_set, train_labels, batch_size)
#      17         elapsed = time.time() - start_time
#      18
#
# <ipython-input-20-363306812d12> in train_mlp(mlp, dataset, labels, batch_size)
#      14
#      15         # Once softmax deltas are set, we may backpropagate errors
# ---> 16         error_backpropagate(mlp, batch)
#      17
#      18         if batch_idx % round(batches_limit / 50) == 0: print("#", end="")
#
# <ipython-input-19-32e21598c342> in error_backpropagate(mlp, batch)
#       2     observations_count = batch.shape[0]
#       3
# ----> 4     error('Error backpropagation is unimplemented')
#       5
#       6     for layer_idx, layer in reversed(list(enumerate(mlp))):
#
# NameError: name 'error' is not defined

# %% [markdown]
# ### Deep neural network

# %%
deep_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM, L2_PENALTY)
]

deep_dbn = [
    Rbm(mlp_layer.visible_size,
        mlp_layer.hidden_size,
        LEARNING_RATE, MOMENTUM, 0.0, L2_PENALTY) for mlp_layer in deep_mlp[:-1]
]

compare_pretraining_results(deep_mlp, deep_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
