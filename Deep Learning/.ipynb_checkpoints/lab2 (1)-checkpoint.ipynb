# %%
import numpy as np
import matplotlib.pyplot as plt
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))

class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, momentum):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:, :-1])
    hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
    visible = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count
    
    return error

# %%
def train_epoch(rbm, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch),  end="\t")
        
        if epoch == 5:
            rbm.momentum = 0.8

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size)
        elapsed = time.time() - start_time
        
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# # 1. RBM Training with momentum

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
       
    positive_hidden[:, :-1] = sigmoid(positive_visible @ rbm.W[:, :-1])
    positive_gradient = positive_visible.transpose() @ positive_hidden
    
    negative_hidden[:, :-1]=(positive_hidden[:,:-1] > rand(observations_count , rbm.hidden_size)).astype(np.float32)
    
    for i in range(k):
        negative_visible[:, :-1]=sigmoid(negative_hidden @ rbm.W[:-1, :].transpose())>rand(observations_count,rbm.visible_size).astype(np.float32)
        negative_hidden[:, :-1]=sigmoid(negative_visible @ rbm.W[:, :-1]) 
        if i<k-1:
            negative_hidden[:,:-1]=(negative_hidden[:,:-1]>rand(observations_count,rbm.hidden_size).astype(np.float32))

    negative_gradient=negative_visible.transpose() @ negative_hidden
    
    rbm.M = rbm.M * rbm.momentum - (-(positive_gradient * rbm.learning_rate) / observations_count + (negative_gradient * rbm.learning_rate) / observations_count)
    rbm.W = rbm.W + rbm.M

# %%
import time

DATASET_SIZE = 5000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
draw_filters(rbm)

run_training(rbm, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)

draw_filters(rbm)
# Out:
# Epoch 0:	########################################	elapsed: 0.45s, reconstruction error: 42.43
# Epoch 1:	########################################	elapsed: 0.44s, reconstruction error: 34.98
# Epoch 2:	########################################	elapsed: 0.42s, reconstruction error: 30.07
# Epoch 3:	########################################	elapsed: 0.41s, reconstruction error: 27.10
# Epoch 4:	########################################	elapsed: 0.42s, reconstruction error: 25.44
# Epoch 5:	########################################	elapsed: 0.54s, reconstruction error: 22.72
# Epoch 6:	########################################	elapsed: 0.48s, reconstruction error: 20.53
# Epoch 7:	########################################	elapsed: 0.50s, reconstruction error: 19.06
# Epoch 8:	########################################	elapsed: 0.48s, reconstruction error: 17.99
# Epoch 9:	########################################	elapsed: 0.47s, reconstruction error: 17.55
# Epoch 10:	########################################	elapsed: 0.47s, reconstruction error: 16.69
# Epoch 11:	########################################	elapsed: 0.48s, reconstruction error: 16.09
# Epoch 12:	########################################	elapsed: 0.46s, reconstruction error: 15.65
# Epoch 13:	########################################	elapsed: 0.46s, reconstruction error: 15.06
# Epoch 14:	########################################	elapsed: 0.46s, reconstruction error: 14.59
# Epoch 15:	########################################	elapsed: 0.47s, reconstruction error: 14.52
# Epoch 16:	########################################	elapsed: 0.49s, reconstruction error: 14.25
# Epoch 17:	########################################	elapsed: 0.47s, reconstruction error: 14.01
# Epoch 18:	########################################	elapsed: 0.46s, reconstruction error: 13.68
# Epoch 19:	########################################	elapsed: 0.49s, reconstruction error: 13.39
# Epoch 20:	########################################	elapsed: 0.49s, reconstruction error: 13.31
# Epoch 21:	########################################	elapsed: 0.49s, reconstruction error: 13.08
# Epoch 22:	########################################	elapsed: 0.45s, reconstruction error: 13.08
# Epoch 23:	########################################	elapsed: 0.40s, reconstruction error: 13.03
# Epoch 24:	########################################	elapsed: 0.40s, reconstruction error: 12.78
# Epoch 25:	########################################	elapsed: 0.40s, reconstruction error: 12.59
# Epoch 26:	########################################	elapsed: 0.39s, reconstruction error: 12.64
# Epoch 27:	########################################	elapsed: 0.40s, reconstruction error: 12.37
# Epoch 28:	########################################	elapsed: 0.40s, reconstruction error: 12.34
# Epoch 29:	########################################	elapsed: 0.40s, reconstruction error: 12.16
# Epoch 30:	########################################	elapsed: 0.54s, reconstruction error: 11.99
# Epoch 31:	########################################	elapsed: 0.47s, reconstruction error: 12.06
# Epoch 32:	########################################	elapsed: 0.47s, reconstruction error: 11.92
# Epoch 33:	########################################	elapsed: 0.46s, reconstruction error: 11.81
# Epoch 34:	########################################	elapsed: 0.41s, reconstruction error: 11.72
# Epoch 35:	########################################	elapsed: 0.45s, reconstruction error: 11.62
# Epoch 36:	########################################	elapsed: 0.41s, reconstruction error: 11.48
# Epoch 37:	########################################	elapsed: 0.40s, reconstruction error: 11.59
# Epoch 38:	########################################	elapsed: 0.41s, reconstruction error: 11.42
# Epoch 39:	########################################	elapsed: 0.42s, reconstruction error: 11.49
# Epoch 40:	########################################	elapsed: 0.44s, reconstruction error: 11.47
# Epoch 41:	########################################	elapsed: 0.41s, reconstruction error: 11.45
# Epoch 42:	########################################	elapsed: 0.38s, reconstruction error: 11.17
# Epoch 43:	########################################	elapsed: 0.41s, reconstruction error: 11.20
# Epoch 44:	########################################	elapsed: 0.41s, reconstruction error: 11.30
# Epoch 45:	########################################	elapsed: 0.42s, reconstruction error: 11.26
# Epoch 46:	########################################	elapsed: 0.42s, reconstruction error: 11.23
# Epoch 47:	########################################	elapsed: 0.45s, reconstruction error: 11.19
# Epoch 48:	########################################	elapsed: 0.45s, reconstruction error: 11.19
# Epoch 49:	########################################	elapsed: 0.47s, reconstruction error: 11.20
# Training finished!

# %% [markdown]
# # 2. DBN Training

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

# %% [markdown]
# ### DBN reconstruction error

# %%
def dbn_reconstuction_error(dbn, layers_count, minibatch):
    minibatch = propagate_up(dbn, layers_count, minibatch)
    error = reconstuction_error(dbn[layers_count], minibatch)
    return error

# %% [markdown]
# ### Sampling in Deep Belief Networks

# %%
def sample_rbm(rbm, minibatch, steps):
    observations_count = minibatch.shape[0]

    visible = minibatch
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    for cd_i in range(steps):
        hidden[:, :-1] = sigmoid(visible @ rbm.W[:, :-1])
        hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
        visible[:, :-1] = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
        if cd_i < (steps - 1):
            visible[:, :-1] = (visible[:, :-1] > rand(observations_count, rbm.visible_size)).astype(np.float32)

    return visible

# %%
def sample_dbn(dbn, layer_idx, minibatch, steps):
    minibatch = propagate_up(dbn, layer_idx, minibatch)
    minibatch = sample_rbm(dbn[layer_idx], minibatch, steps)
    minibatch = propagate_down(dbn, layer_idx, minibatch)
    return minibatch

# %%
def draw_layer_samples(dbn, layer_idx, minibatch, steps=200):
    samples = sample_dbn(dbn, layer_idx, minibatch, steps)
    tiles(np.reshape(samples[:, :-1], newshape=(-1, 16, 28, 28)))

# %% [markdown]
# ### Greedy layer-wise training

# %%
def train_dbn(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)

    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

DBN_HIDDEN_LAYER_SIZE = 200
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
]

for layer_idx in range(len(dbn)):
    print("\nLearning layer {}".format(layer_idx))

    for epoch in range(EPOCHS_COUNT):
        print("Epoch {}:".format(epoch),  end="\t")

        if epoch == 5:
            dbn[layer_idx].momentum = 0.8
        
        start_time = time.time()
        train_dbn(dbn, layer_idx, dataset, BATCH_SIZE)
        elapsed = time.time() - start_time
        
        error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))
    
print("Training finished!")
# Out:
# Learning layer 0
# Epoch 0:	########################################	elapsed: 0.51s, reconstruction error: 42.34
# Epoch 1:	########################################	elapsed: 0.56s, reconstruction error: 33.49
# Epoch 2:	########################################	elapsed: 0.54s, reconstruction error: 29.47
# Epoch 3:	########################################	elapsed: 0.49s, reconstruction error: 25.93
# Epoch 4:	########################################	elapsed: 0.50s, reconstruction error: 23.57
# Epoch 5:	########################################	elapsed: 0.51s, reconstruction error: 20.97
# Epoch 6:	########################################	elapsed: 0.52s, reconstruction error: 19.00
# Epoch 7:	########################################	elapsed: 0.50s, reconstruction error: 17.29
# Epoch 8:	########################################	elapsed: 0.51s, reconstruction error: 16.01
# Epoch 9:	########################################	elapsed: 0.53s, reconstruction error: 15.32
# Epoch 10:	########################################	elapsed: 0.52s, reconstruction error: 14.71
# Epoch 11:	########################################	elapsed: 0.52s, reconstruction error: 14.19
# Epoch 12:	########################################	elapsed: 0.55s, reconstruction error: 13.55
# Epoch 13:	########################################	elapsed: 0.52s, reconstruction error: 13.43
# Epoch 14:	########################################	elapsed: 0.54s, reconstruction error: 13.11
# Epoch 15:	########################################	elapsed: 0.53s, reconstruction error: 12.60
# Epoch 16:	########################################	elapsed: 0.54s, reconstruction error: 12.33
# Epoch 17:	########################################	elapsed: 0.57s, reconstruction error: 12.12
# Epoch 18:	########################################	elapsed: 0.57s, reconstruction error: 11.67
# Epoch 19:	########################################	elapsed: 0.63s, reconstruction error: 11.72
# Epoch 20:	########################################	elapsed: 0.64s, reconstruction error: 11.75
# Epoch 21:	########################################	elapsed: 0.62s, reconstruction error: 11.38
# Epoch 22:	########################################	elapsed: 0.63s, reconstruction error: 11.09
# Epoch 23:	########################################	elapsed: 0.64s, reconstruction error: 11.00
# Epoch 24:	########################################	elapsed: 0.67s, reconstruction error: 10.87
# Epoch 25:	########################################	elapsed: 0.60s, reconstruction error: 10.66
# Epoch 26:	########################################	elapsed: 0.62s, reconstruction error: 10.55
# Epoch 27:	########################################	elapsed: 0.64s, reconstruction error: 10.58
# Epoch 28:	########################################	elapsed: 0.59s, reconstruction error: 10.39
# Epoch 29:	########################################	elapsed: 0.60s, reconstruction error: 10.20
# Epoch 30:	########################################	elapsed: 0.61s, reconstruction error: 10.22
# Epoch 31:	########################################	elapsed: 0.61s, reconstruction error: 10.19
# Epoch 32:	########################################	elapsed: 0.60s, reconstruction error: 10.11
# Epoch 33:	########################################	elapsed: 0.65s, reconstruction error: 10.01
# Epoch 34:	########################################	elapsed: 0.70s, reconstruction error: 10.03
# Epoch 35:	########################################	elapsed: 0.67s, reconstruction error: 10.14
# Epoch 36:	########################################	elapsed: 0.67s, reconstruction error: 9.81
# Epoch 37:	########################################	elapsed: 0.56s, reconstruction error: 9.93
# Epoch 38:	########################################	elapsed: 0.61s, reconstruction error: 9.93
# Epoch 39:	########################################	elapsed: 0.63s, reconstruction error: 9.77
# Epoch 40:	########################################	elapsed: 0.53s, reconstruction error: 9.35
# Epoch 41:	########################################	elapsed: 0.53s, reconstruction error: 9.64
# Epoch 42:	########################################	elapsed: 0.56s, reconstruction error: 9.61
# Epoch 43:	########################################	elapsed: 0.55s, reconstruction error: 9.43
# Epoch 44:	########################################	elapsed: 0.54s, reconstruction error: 9.39
# Epoch 45:	########################################	elapsed: 0.54s, reconstruction error: 9.21
# Epoch 46:	########################################	elapsed: 0.56s, reconstruction error: 9.35
# Epoch 47:	########################################	elapsed: 0.60s, reconstruction error: 9.05
# Epoch 48:	########################################	elapsed: 0.59s, reconstruction error: 9.13
# Epoch 49:	########################################	elapsed: 0.57s, reconstruction error: 9.24
#
# Learning layer 1
# Epoch 0:	########################################	elapsed: 0.26s, reconstruction error: 25.18
# Epoch 1:	########################################	elapsed: 0.27s, reconstruction error: 19.54
# Epoch 2:	########################################	elapsed: 0.25s, reconstruction error: 16.15
# Epoch 3:	########################################	elapsed: 0.26s, reconstruction error: 14.82
# Epoch 4:	########################################	elapsed: 0.25s, reconstruction error: 13.12
# Epoch 5:	########################################	elapsed: 0.26s, reconstruction error: 11.36
# Epoch 6:	########################################	elapsed: 0.28s, reconstruction error: 10.02
# Epoch 7:	########################################	elapsed: 0.28s, reconstruction error: 9.08
# Epoch 8:	########################################	elapsed: 0.26s, reconstruction error: 8.27
# Epoch 9:	########################################	elapsed: 0.25s, reconstruction error: 7.75
# Epoch 10:	########################################	elapsed: 0.27s, reconstruction error: 7.51
# Epoch 11:	########################################	elapsed: 0.26s, reconstruction error: 7.14
# Epoch 12:	########################################	elapsed: 0.27s, reconstruction error: 6.87
# Epoch 13:	########################################	elapsed: 0.25s, reconstruction error: 6.57
# Epoch 14:	########################################	elapsed: 0.25s, reconstruction error: 6.44
# Epoch 15:	########################################	elapsed: 0.27s, reconstruction error: 6.20
# Epoch 16:	########################################	elapsed: 0.28s, reconstruction error: 6.02
# Epoch 17:	########################################	elapsed: 0.32s, reconstruction error: 5.98
# Epoch 18:	########################################	elapsed: 0.31s, reconstruction error: 5.92
# Epoch 19:	########################################	elapsed: 0.31s, reconstruction error: 5.72
# Epoch 20:	########################################	elapsed: 0.27s, reconstruction error: 5.61
# Epoch 21:	########################################	elapsed: 0.27s, reconstruction error: 5.55
# Epoch 22:	########################################	elapsed: 0.26s, reconstruction error: 5.45
# Epoch 23:	########################################	elapsed: 0.30s, reconstruction error: 5.55
# Epoch 24:	########################################	elapsed: 0.26s, reconstruction error: 5.39
# Epoch 25:	########################################	elapsed: 0.30s, reconstruction error: 5.37
# Epoch 26:	########################################	elapsed: 0.27s, reconstruction error: 5.28
# Epoch 27:	########################################	elapsed: 0.26s, reconstruction error: 5.19
# Epoch 28:	########################################	elapsed: 0.27s, reconstruction error: 5.20
# Epoch 29:	########################################	elapsed: 0.28s, reconstruction error: 5.05
# Epoch 30:	########################################	elapsed: 0.28s, reconstruction error: 5.06
# Epoch 31:	########################################	elapsed: 0.28s, reconstruction error: 5.07
# Epoch 32:	########################################	elapsed: 0.28s, reconstruction error: 5.04
# Epoch 33:	########################################	elapsed: 0.34s, reconstruction error: 4.95
# Epoch 34:	########################################	elapsed: 0.37s, reconstruction error: 4.99
# Epoch 35:	########################################	elapsed: 0.36s, reconstruction error: 4.88
# Epoch 36:	########################################	elapsed: 0.30s, reconstruction error: 4.74
# Epoch 37:	########################################	elapsed: 0.28s, reconstruction error: 4.81
# Epoch 38:	########################################	elapsed: 0.30s, reconstruction error: 4.76
# Epoch 39:	########################################	elapsed: 0.31s, reconstruction error: 4.77
# Epoch 40:	########################################	elapsed: 0.26s, reconstruction error: 4.80
# Epoch 41:	########################################	elapsed: 0.27s, reconstruction error: 4.75
# Epoch 42:	########################################	elapsed: 0.26s, reconstruction error: 4.74
# Epoch 43:	########################################	elapsed: 0.30s, reconstruction error: 4.76
# Epoch 44:	########################################	elapsed: 0.29s, reconstruction error: 4.68
# Epoch 45:	########################################	elapsed: 0.26s, reconstruction error: 4.61
# Epoch 46:	########################################	elapsed: 0.27s, reconstruction error: 4.72
# Epoch 47:	########################################	elapsed: 0.26s, reconstruction error: 4.67
# Epoch 48:	########################################	elapsed: 0.27s, reconstruction error: 4.54
# Epoch 49:	########################################	elapsed: 0.30s, reconstruction error: 4.46
#
# Learning layer 2
# Epoch 0:	########################################	elapsed: 0.31s, reconstruction error: 18.75
# Epoch 1:	########################################	elapsed: 0.35s, reconstruction error: 13.91
# Epoch 2:	########################################	elapsed: 0.36s, reconstruction error: 11.36
# Epoch 3:	########################################	elapsed: 0.32s, reconstruction error: 10.08
# Epoch 4:	########################################	elapsed: 0.34s, reconstruction error: 8.99
# Epoch 5:	########################################	elapsed: 0.33s, reconstruction error: 7.31
# Epoch 6:	########################################	elapsed: 0.31s, reconstruction error: 6.30
# Epoch 7:	########################################	elapsed: 0.31s, reconstruction error: 5.69
# Epoch 8:	########################################	elapsed: 0.37s, reconstruction error: 5.22
# Epoch 9:	########################################	elapsed: 0.35s, reconstruction error: 5.03
# Epoch 10:	########################################	elapsed: 0.36s, reconstruction error: 4.75
# Epoch 11:	########################################	elapsed: 0.36s, reconstruction error: 4.63
# Epoch 12:	########################################	elapsed: 0.35s, reconstruction error: 4.46
# Epoch 13:	########################################	elapsed: 0.37s, reconstruction error: 4.30
# Epoch 14:	########################################	elapsed: 0.34s, reconstruction error: 4.04
# Epoch 15:	########################################	elapsed: 0.34s, reconstruction error: 4.01
# Epoch 16:	########################################	elapsed: 0.33s, reconstruction error: 3.94
# Epoch 17:	########################################	elapsed: 0.31s, reconstruction error: 3.84
# Epoch 18:	########################################	elapsed: 0.31s, reconstruction error: 3.85
# Epoch 19:	########################################	elapsed: 0.30s, reconstruction error: 3.66
# Epoch 20:	########################################	elapsed: 0.31s, reconstruction error: 3.72
# Epoch 21:	########################################	elapsed: 0.29s, reconstruction error: 3.60
# Epoch 22:	########################################	elapsed: 0.30s, reconstruction error: 3.58
# Epoch 23:	########################################	elapsed: 0.30s, reconstruction error: 3.58
# Epoch 24:	########################################	elapsed: 0.29s, reconstruction error: 3.61
# Epoch 25:	########################################	elapsed: 0.30s, reconstruction error: 3.50
# Epoch 26:	########################################	elapsed: 0.34s, reconstruction error: 3.42
# Epoch 27:	########################################	elapsed: 0.30s, reconstruction error: 3.48
# Epoch 28:	########################################	elapsed: 0.29s, reconstruction error: 3.37
# Epoch 29:	########################################	elapsed: 0.31s, reconstruction error: 3.41
# Epoch 30:	########################################	elapsed: 0.29s, reconstruction error: 3.32
# Epoch 31:	########################################	elapsed: 0.33s, reconstruction error: 3.28
# Epoch 32:	########################################	elapsed: 0.31s, reconstruction error: 3.37
# Epoch 33:	########################################	elapsed: 0.29s, reconstruction error: 3.31
# Epoch 34:	########################################	elapsed: 0.29s, reconstruction error: 3.32
# Epoch 35:	########################################	elapsed: 0.29s, reconstruction error: 3.33
# Epoch 36:	########################################	elapsed: 0.29s, reconstruction error: 3.21
# Epoch 37:	########################################	elapsed: 0.30s, reconstruction error: 3.27
# Epoch 38:	########################################	elapsed: 0.31s, reconstruction error: 3.22
# Epoch 39:	########################################	elapsed: 0.30s, reconstruction error: 3.27
# Epoch 40:	########################################	elapsed: 0.31s, reconstruction error: 3.24
# Epoch 41:	########################################	elapsed: 0.29s, reconstruction error: 3.18
# Epoch 42:	########################################	elapsed: 0.34s, reconstruction error: 3.07
# Epoch 43:	########################################	elapsed: 0.29s, reconstruction error: 3.21
# Epoch 44:	########################################	elapsed: 0.32s, reconstruction error: 3.11
# Epoch 45:	########################################	elapsed: 0.29s, reconstruction error: 3.09
# Epoch 46:	########################################	elapsed: 0.29s, reconstruction error: 3.02
# Epoch 47:	########################################	elapsed: 0.28s, reconstruction error: 3.09
# Epoch 48:	########################################	elapsed: 0.31s, reconstruction error: 3.20
# Epoch 49:	########################################	elapsed: 0.29s, reconstruction error: 3.00
# Training finished!

# %%
draw_layer_samples(dbn, 0, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 1, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 2, monitoring_set[:8*16])
